# %%
import pandas as pd
import numpy as np

# %%
# To drop the record containing missinng values
# df.dropna(how='any')

# To drop the row if all the values in the row are missing
# df.dropna(how='all')

# doesnt make inplace changes

# df.isnull().sum() tells you the mising values

# %%
# Converting categorical data to numerical
# df["rating"] = np.where(df["Rating"].isin(["good", "bad"]), 1, 0)

# %%
# Now fico-range is a chr column containing numerical data. But it cannot be converted directly to numerical due to spl symbols
# df["fico-range"].split("-")
# this will give u error

# Split is a string operation. To solve this let us use str.split
# df["fico-range"].str.solit("-")

# But the above one gives the output as list. to get the output in sep column
# df["fico-range"].str.split("-", expand=True)

# to concatenate this to data frame
# bank_df[["low", "high"]] = bank_df["FICO.Range"].str.split("-", expand=True)

# %%
# To convert string to numeric
# df["Fico-range"] = df["Fico-range"].astype(float)

# %%
# If a categorical variable has n distinct categories then we need to create n-1 dummies

# df["CityMum"] = np.where(df["City"] == "Mumbai", 1, 0).astype(int)
# This is manual way of creating dummies and requires lot of codding

# %%
# We can directly use get_dummies from pandas to automatically create dummies
# dummy = pd.get_dummies(df["City"], drop_first = True, prefix="City")
# drop_first to create n-1 dummies
# prefix is names of dummy var starting with

# %%
mtcars_df = pd.read_csv(r"C:\users\vinay\Data sets\mtcars.csv")
mtcars_df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars_df.shape
# Out:
# (32, 12)

# %%
list(zip(mtcars_df.columns, mtcars_df.dtypes, mtcars_df.nunique()))
# Out:
# [('Unnamed: 0', dtype('O'), 32),
#  ('mpg', dtype('float64'), 25),
#  ('cyl', dtype('int64'), 3),
#  ('disp', dtype('float64'), 27),
#  ('hp', dtype('int64'), 22),
#  ('drat', dtype('float64'), 22),
#  ('wt', dtype('float64'), 29),
#  ('qsec', dtype('float64'), 30),
#  ('vs', dtype('int64'), 2),
#  ('am', dtype('int64'), 2),
#  ('gear', dtype('int64'), 3),
#  ('carb', dtype('int64'), 6)]

# %%
mtcars_df.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
mtcars_df.dtypes
# Out:
# Unnamed: 0     object
# mpg           float64
# cyl             int64
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs              int64
# am              int64
# gear            int64
# carb            int64
# dtype: object

# %%
mtcars_df.nunique()
# Out:
# Unnamed: 0    32
# mpg           25
# cyl            3
# disp          27
# hp            22
# drat          22
# wt            29
# qsec          30
# vs             2
# am             2
# gear           3
# carb           6
# dtype: int64

# %%
mtcars_df.isnull().sum()
# Out:
# Unnamed: 0    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
# For deleting nan values we use how =  any or all
mtcars_df = mtcars_df.dropna(how = 'any')

# %%
mtcars_df.isnull().sum()
# Out:
# Unnamed: 0    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
# after deletion we should check are shape
mtcars_df.shape
# Out:
# (32, 12)

# %%
mtcars_df["gear"].unique()
# Out:
# array([4, 3, 5], dtype=int64)

# %%
mtcars_df["gear"].nunique()
# Out:
# 3

# %%
mtcars_df["gear"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
# dropna = False give you NAN counts also
mtcars_df["gear"].value_counts(dropna=False) 
# in this case we dont have nan values
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
# Converting data to 1 0
mtcars_df['3gears'] = np.where(mtcars_df['gear']==3, 1, 0)
mtcars_df['4gears'] = np.where(mtcars_df['gear']==4, 1, 0)
mtcars_df['5gears'] = np.where(mtcars_df['gear']==5, 1, 0)

# del mtcars_df['gear']
mtcars_df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...
